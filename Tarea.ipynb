# %% [markdown]
# <a href="https://colab.research.google.com/github/xsayaa/AI/blob/main/Tarea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sadya Mariana Martínez Fuerte - 1957307

# %%
from google.colab import drive

drive.mount('/content/drive')


#Una vez que cargue la celda autorizar permisos por medio de la ventana que se va a abrir
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from PIL import Image

from IPython.display import display

import numpy as np

# %%
image_path = "/content/drive/MyDrive/Ingeniería Biomédica FIME/7mo Semestre/Imagenes Médicas/cateterismocardiaco.jpg"

# %%
img = Image.open(image_path)
img2 = np.asarray(img)
img3 = (1-(img2))
img4 = Image.fromarray(img3)
display(img4)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
